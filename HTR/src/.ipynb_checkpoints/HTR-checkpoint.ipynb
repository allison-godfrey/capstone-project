# %%
# %%javascript
#
# // apply setting to all current CodeMirror instances
# IPython.notebook.get_cells().map(
# 	function(c) {  return c.code_mirror.options.indentWithTabs=true;  }
# );
#
# // make sure new CodeMirror instances created in the future also use this setting
# CodeMirror.defaults.indentWithTabs=true;

# %%
import os, sys
import warnings
import tensorflow as tf
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image

import argparse
import json

import cv2
import editdistance
from path import Path

from DataLoaderIAM import DataLoaderIAM, Batch
from Model import Model, DecoderType
from SamplePreprocessor import preprocess

# %%
class FilePaths:
	"filenames and paths to data"
	fnCharList = '../model/charList.txt'
	fnSummary = '../model/summary.json'
	fnInfer = '../data/test.png'
	fnCorpus = '../data/corpus.txt'


def write_summary(charErrorRates, wordAccuracies):
	with open(FilePaths.fnSummary, 'w') as f:
		json.dump({'charErrorRates': charErrorRates, 'wordAccuracies': wordAccuracies}, f)


def train(model, loader):
	"train NN"
	epoch = 0  # number of training epochs since start
	summaryCharErrorRates = []
	summaryWordAccuracies = []
	bestCharErrorRate = float('inf')  # best valdiation character error rate
	noImprovementSince = 0  # number of epochs no improvement of character error rate occured
	earlyStopping = 25  # stop training after this number of epochs without improvement
	while True:
		epoch += 1
		print('Epoch:', epoch)

		# train
		print('Train NN')
		loader.trainSet()
		while loader.hasNext():
			iterInfo = loader.getIteratorInfo()
			batch = loader.getNext()
			loss = model.trainBatch(batch)
			print(f'Epoch: {epoch} Batch: {iterInfo[0]}/{iterInfo[1]} Loss: {loss}')

		# validate
		charErrorRate, wordAccuracy = validate(model, loader)

		# write summary
		summaryCharErrorRates.append(charErrorRate)
		summaryWordAccuracies.append(wordAccuracy)
		write_summary(summaryCharErrorRates, summaryWordAccuracies)

		# if best validation accuracy so far, save model parameters
		if charErrorRate < bestCharErrorRate:
			print('Character error rate improved, save model')
			bestCharErrorRate = charErrorRate
			noImprovementSince = 0
			model.save()
		else:
			print(f'Character error rate not improved, best so far: {charErrorRate * 100.0}%')
			noImprovementSince += 1

		# stop training if no more improvement in the last x epochs
		if noImprovementSince >= earlyStopping:
			print(f'No more improvement since {earlyStopping} epochs. Training stopped.')
			break


def validate(model, loader):
	"validate NN"
	print('Validate NN')
	loader.validationSet()
	numCharErr = 0
	numCharTotal = 0
	numWordOK = 0
	numWordTotal = 0
	while loader.hasNext():
		iterInfo = loader.getIteratorInfo()
		print(f'Batch: {iterInfo[0]} / {iterInfo[1]}')
		batch = loader.getNext()
		(recognized, _) = model.inferBatch(batch)

		print('Ground truth -> Recognized')
		for i in range(len(recognized)):
			numWordOK += 1 if batch.gtTexts[i] == recognized[i] else 0
			numWordTotal += 1
			dist = editdistance.eval(recognized[i], batch.gtTexts[i])
			numCharErr += dist
			numCharTotal += len(batch.gtTexts[i])
			print('[OK]' if dist == 0 else '[ERR:%d]' % dist, '"' + batch.gtTexts[i] + '"', '->',
				  '"' + recognized[i] + '"')

	# print validation result
	charErrorRate = numCharErr / numCharTotal
	wordAccuracy = numWordOK / numWordTotal
	print(f'Character error rate: {charErrorRate * 100.0}%. Word accuracy: {wordAccuracy * 100.0}%.')
	return charErrorRate, wordAccuracy


def infer(model, fnImg):
	"recognize text in image provided by file path"
	img = preprocess(cv2.imread(fnImg, cv2.IMREAD_GRAYSCALE), Model.imgSize)
	batch = Batch(None, [img])
	(recognized, probability) = model.inferBatch(batch, True)
# 	print(f'Recognized: "{recognized[0]}
# 	print(f'Probability: {probability[0]}')
	return (recognized[0],probability[0])

# %%
def main():
	tf.compat.v1.reset_default_graph()

	"main function"
	sys.argv = []
	parser = argparse.ArgumentParser(sys.argv)
	parser.add_argument('--train', help='train the NN', action='store_true')
	parser.add_argument('--validate', help='validate the NN', action='store_true')
	parser.add_argument('--decoder', choices=['bestpath', 'beamsearch', 'wordbeamsearch'], default='bestpath',
						help='CTC decoder')
	parser.add_argument('--batch_size', help='batch size', type=int, default=100)
	parser.add_argument('--data_dir', help='directory containing IAM dataset', type=Path, required=False)
	parser.add_argument('--fast', help='use lmdb to load images', action='store_true')
	parser.add_argument('--dump', help='dump output of NN to CSV file(s)', action='store_true')
	args = parser.parse_args()
	
# 	args.validate = True
	args.data_dir = Path('../../collectedData/sliced/response_004/img')
	print("\n********")
	print(args)
	print(vars(args))
	print(args.data_dir)
	print("********\n")

	
	# set chosen CTC decoder
	if args.decoder == 'bestpath':
		decoderType = DecoderType.BestPath
	elif args.decoder == 'beamsearch':
		decoderType = DecoderType.BeamSearch
	elif args.decoder == 'wordbeamsearch':
		decoderType = DecoderType.WordBeamSearch

	# train or validate on IAM dataset
	if args.train or args.validate:
		# load training data, create TF model
		loader = DataLoaderIAM(args.data_dir, args.batch_size, Model.imgSize, Model.maxTextLen, args.fast)

		# save characters of model for inference mode
		open(FilePaths.fnCharList, 'w').write(str().join(loader.charList))

		# save words contained in dataset into file
		open(FilePaths.fnCorpus, 'w').write(str(' ').join(loader.trainWords + loader.validationWords))

		# execute training or validation
		if args.train:
			model = Model(loader.charList, decoderType)
			train(model, loader)
		elif args.validate:
			model = Model(loader.charList, decoderType, mustRestore=True)
			validate(model, loader)

	# infer text on test images
	else:
		df = pd.DataFrame(columns=['Actual','Guess','Conf','Result','Path'])
		model = Model(open(FilePaths.fnCharList).read(), decoderType, mustRestore=True, dump=args.dump)
		for sample in os.listdir(args.data_dir):
			guess, conf = infer(model, os.path.join(args.data_dir,sample))
			actual = re.sub('((\W+\(\d*\))?\.((png)|(jpg)))','',sample)
			result = actual==guess
# 			print('Actual:\t', actual)
# 			print('Guess:\t', guess)
# 			print('Conf:\t ', conf)
# 			print('\t', result)
# 			print()
			df = df.append(pd.Series([actual, guess, conf, result,os.path.join(args.data_dir,sample)], index = df.columns), ignore_index=True)
			
		return df

if __name__ == '__main__':
	df = main()
	display(df)
# Out:
# ********
# Namespace(batch_size=100, data_dir=Path('../../collectedData/raw/sliced/response_004/img'), decoder='bestpath', dump=False, fast=False, train=False, validate=False)
# {'train': False, 'validate': False, 'decoder': 'bestpath', 'batch_size': 100, 'data_dir': Path('../../collectedData/raw/sliced/response_004/img'), 'fast': False, 'dump': False}
# ../../collectedData/raw/sliced/response_004/img
# ********
# C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\normalization.py:308: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   '`tf.layers.batch_normalization` is deprecated and '
# C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\mrkawa\Documents\Berkeley\w210\capstone-project\SimpleHTR\src\Model.py:91: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\ops\rnn.py:447: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:981: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:903: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\mrkawa\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Python: 3.6.12 |Anaconda, Inc.| (default, Sep  9 2020, 00:29:25) [MSC v.1916 64 bit (AMD64)]
# Tensorflow: 2.4.1
# Init with stored values from ../model/snapshot-39
# INFO:tensorflow:Restoring parameters from ../model/snapshot-39
#      Actual   Guess      Conf Result  \
# 0     'real    Ered  0.178206  False
# 1                 #  0.895838  False
# 2         a       a  0.840182   True
# 3    active  ective  0.160548  False
# 4    active  actove  0.108019  False
# ..      ...     ...       ...    ...
# 82     will     mrl  0.094767  False
# 83     will    will  0.958030   True
# 84  world'.   ward'  0.090249  False
# 85     year    year  0.503542   True
# 86      Yes      Ye  0.373758  False
#
#                                                  Path
# 0   ../../collectedData/raw/sliced/response_004/im...
# 1   ../../collectedData/raw/sliced/response_004/im...
# 2   ../../collectedData/raw/sliced/response_004/im...
# 3   ../../collectedData/raw/sliced/response_004/im...
# 4   ../../collectedData/raw/sliced/response_004/im...
# ..                                                ...
# 82  ../../collectedData/raw/sliced/response_004/im...
# 83  ../../collectedData/raw/sliced/response_004/im...
# 84  ../../collectedData/raw/sliced/response_004/im...
# 85  ../../collectedData/raw/sliced/response_004/im...
# 86  ../../collectedData/raw/sliced/response_004/im...
#
# [87 rows x 5 columns]

# %%
df.Result.value_counts()
# Out:
# False    58
# True     29
# Name: Result, dtype: int64

# %%
plt.hist(df[df.Result==False].Conf, color='red', bins=20, alpha=0.75)
plt.hist(df[df.Result==True].Conf, color='green', bins=20, alpha=0.5)
plt.ylabel('# of Samples')
plt.xlabel('Confidence')
plt.legend(['Incorrect','Correct'])
plt.show()

# %%
# %matplotlib inline

for tup in df.itertuples():
	print('Actual:\t', tup.Actual)
	print('Guess:\t', tup.Guess)
	print('Conf:\t ', tup.Conf)
	print('\t', tup.Result)
	im = Image.open(tup.Path)
	imshow(np.asarray(im))
	plt.show()
	print('***************************************************************************************************************')
# Out:
# Actual:	 'real
# Guess:	 Ered
# Conf:	  0.17820589244365692
# 	 False
# ***************************************************************************************************************
# Actual:
# Guess:	 #
# Conf:	  0.8958377242088318
# 	 False
# ***************************************************************************************************************
# Actual:	 a
# Guess:	 a
# Conf:	  0.840182363986969
# 	 True
# ***************************************************************************************************************
# Actual:	 active
# Guess:	 ective
# Conf:	  0.16054795682430267
# 	 False
# ***************************************************************************************************************
# Actual:	 active
# Guess:	 actove
# Conf:	  0.10801918059587479
# 	 False
# ***************************************************************************************************************
# Actual:	 activity
# Guess:	 acht
# Conf:	  0.007581246085464954
# 	 False
# ***************************************************************************************************************
# Actual:	 all
# Guess:	 all
# Conf:	  0.0713331401348114
# 	 True
# ***************************************************************************************************************
# Actual:	 also
# Guess:	 also
# Conf:	  0.9463518857955933
# 	 True
# ***************************************************************************************************************
# Actual:	 and
# Guess:	 wtd
# Conf:	  0.06556740403175354
# 	 False
# ***************************************************************************************************************
# Actual:	 and
# Guess:	 es
# Conf:	  0.14585629105567932
# 	 False
# ***************************************************************************************************************
# Actual:	 And
# Guess:	 Aad
# Conf:	  0.3891063928604126
# 	 False
# ***************************************************************************************************************
# Actual:	 and
# Guess:	 aod
# Conf:	  0.19607402384281158
# 	 False
# ***************************************************************************************************************
# Actual:	 and
# Guess:	 aid
# Conf:	  0.3420909345149994
# 	 False
# ***************************************************************************************************************
# Actual:	 and
# Guess:	 ad
# Conf:	  0.405406653881073
# 	 False
# ***************************************************************************************************************
# Actual:	 are
# Guess:	 bre
# Conf:	  0.816887617111206
# 	 False
# ***************************************************************************************************************
# Actual:	 be
# Guess:	 be
# Conf:	  0.9772624373435974
# 	 True
# ***************************************************************************************************************
# Actual:	 become
# Guess:	 becane
# Conf:	  0.32808899879455566
# 	 False
# ***************************************************************************************************************
# Actual:	 becoming
# Guess:	 becamin
# Conf:	  0.05595998466014862
# 	 False
# ***************************************************************************************************************
# Actual:	 believe
# Guess:	 beheve
# Conf:	  0.6469181180000305
# 	 False
# ***************************************************************************************************************
# Actual:	 better
# Guess:	 better
# Conf:	  0.9427881240844727
# 	 True
# ***************************************************************************************************************
# Actual:	 By
# Guess:	 by
# Conf:	  0.24784934520721436
# 	 False
# ***************************************************************************************************************
# Actual:	 by
# Guess:	 bx
# Conf:	  0.4158320128917694
# 	 False
# ***************************************************************************************************************
# Actual:	 ee
# Guess:	 need
# Conf:	  0.27507591247558594
# 	 False
# ***************************************************************************************************************
# Actual:	 every
# Guess:	 every
# Conf:	  0.7776661515235901
# 	 True
# ***************************************************************************************************************
# Actual:	 everyday
# Guess:	 everda
# Conf:	  0.15962627530097961
# 	 False
# ***************************************************************************************************************
# Actual:	 fat.
# Guess:	 sake
# Conf:	  0.13751864433288574
# 	 False
# ***************************************************************************************************************
# Actual:	 for
# Guess:	 for
# Conf:	  0.8395755290985107
# 	 True
# ***************************************************************************************************************
# Actual:	 gym
# Guess:	 gyne
# Conf:	  0.15975502133369446
# 	 False
# ***************************************************************************************************************
# Actual:	 having
# Guess:	 hovrns
# Conf:	  0.1144966334104538
# 	 False
# ***************************************************************************************************************
# Actual:	 He
# Guess:	 He
# Conf:	  0.9440712928771973
# 	 True
# ***************************************************************************************************************
# Actual:	 help
# Guess:	 hele
# Conf:	  0.46819543838500977
# 	 False
# ***************************************************************************************************************
# Actual:	 help
# Guess:	 hele
# Conf:	  0.6620155572891235
# 	 False
# ***************************************************************************************************************
# Actual:	 highschool,
# Guess:	 Hubzchoale
# Conf:	  0.0019714757800102234
# 	 False
# ***************************************************************************************************************
# Actual:	 how
# Guess:	 hew
# Conf:	  0.28529268503189087
# 	 False
# ***************************************************************************************************************
# Actual:	 I
# Guess:	 I
# Conf:	  0.9146043062210083
# 	 True
# ***************************************************************************************************************
# Actual:	 img304
# Guess:	 a
# Conf:	  0.9615039229393005
# 	 False
# ***************************************************************************************************************
# Actual:	 in
# Guess:	 in
# Conf:	  0.9936862587928772
# 	 True
# ***************************************************************************************************************
# Actual:	 in
# Guess:	 in
# Conf:	  0.9008249640464783
# 	 True
# ***************************************************************************************************************
# Actual:	 It
# Guess:	 it
# Conf:	  0.7260109186172485
# 	 False
# ***************************************************************************************************************
# Actual:	 keep
# Guess:	 kesp
# Conf:	  0.13573968410491943
# 	 False
# ***************************************************************************************************************
# Actual:	 keep
# Guess:	 keep
# Conf:	  0.704591691493988
# 	 True
# ***************************************************************************************************************
# Actual:	 lazy
# Guess:	 teat
# Conf:	  0.05426330491900444
# 	 False
# ***************************************************************************************************************
# Actual:	 leadership
# Guess:	 teaderhip
# Conf:	  0.14012935757637024
# 	 False
# ***************************************************************************************************************
# Actual:	 learn
# Guess:	 learn
# Conf:	  0.34073328971862793
# 	 True
# ***************************************************************************************************************
# Actual:	 lifestyle.
# Guess:	 fesple
# Conf:	  0.017525140196084976
# 	 False
# ***************************************************************************************************************
# Actual:	 live
# Guess:	 tive
# Conf:	  0.32296329736709595
# 	 False
# ***************************************************************************************************************
# Actual:	 Many
# Guess:	 Macy
# Conf:	  0.20509052276611328
# 	 False
# ***************************************************************************************************************
# Actual:	 need
# Guess:	 need
# Conf:	  0.9480076432228088
# 	 True
# ***************************************************************************************************************
# Actual:	 or
# Guess:	 ,r
# Conf:	  0.023847034201025963
# 	 False
# ***************************************************************************************************************
# Actual:	 P.E
# Guess:	 P.E
# Conf:	  0.33226317167282104
# 	 True
# ***************************************************************************************************************
# Actual:	 P.E.
# Guess:	 RE.
# Conf:	  0.34410011768341064
# 	 False
# ***************************************************************************************************************
# Actual:	 participate
# Guess:	 eparkccspate
# Conf:	  0.020703813061118126
# 	 False
# ***************************************************************************************************************
# Actual:	 participating
# Guess:	 perticipatios
# Conf:	  0.014085451140999794
# 	 False
# ***************************************************************************************************************
# Actual:	 people
# Guess:	 Recple
# Conf:	  0.19532743096351624
# 	 False
# ***************************************************************************************************************
# Actual:	 person.
# Guess:	 secse
# Conf:	  0.07172560691833496
# 	 False
# ***************************************************************************************************************
# Actual:	 physical
# Guess:	 plysical
# Conf:	  0.656473696231842
# 	 False
# ***************************************************************************************************************
# Actual:	 required
# Guess:	 sequiced
# Conf:	  0.15990664064884186
# 	 False
# ***************************************************************************************************************
# Actual:	 should
# Guess:	 should
# Conf:	  0.7065268754959106
# 	 True
# ***************************************************************************************************************
# Actual:	 shows
# Guess:	 shawis
# Conf:	  0.2240631878376007
# 	 False
# ***************************************************************************************************************
# Actual:	 skills
# Guess:	 skls
# Conf:	  0.10088267922401428
# 	 False
# ***************************************************************************************************************
# Actual:	 student
# Guess:	 student
# Conf:	  0.27096107602119446
# 	 True
# ***************************************************************************************************************
# Actual:	 students
# Guess:	 Studerk
# Conf:	  0.27780741453170776
# 	 False
# ***************************************************************************************************************
# Actual:	 students
# Guess:	 students
# Conf:	  0.7422018051147461
# 	 True
# ***************************************************************************************************************
# Actual:	 students
# Guess:	 students
# Conf:	  0.7214392423629761
# 	 True
# ***************************************************************************************************************
# Actual:	 take
# Guess:	 take
# Conf:	  0.5625144839286804
# 	 True
# ***************************************************************************************************************
# Actual:	 teens
# Guess:	 teens
# Conf:	  0.8625832200050354
# 	 True
# ***************************************************************************************************************
# Actual:	 that
# Guess:	 thet
# Conf:	  0.3110785484313965
# 	 False
# ***************************************************************************************************************
# Actual:	 that
# Guess:	 thot
# Conf:	  0.38688012957572937
# 	 False
# ***************************************************************************************************************
# Actual:	 the
# Guess:	 the
# Conf:	  0.9929110407829285
# 	 True
# ***************************************************************************************************************
# Actual:	 them
# Guess:	 thes
# Conf:	  0.34396034479141235
# 	 False
# ***************************************************************************************************************
# Actual:	 them.
# Guess:	 them
# Conf:	  0.6005826592445374
# 	 False
# ***************************************************************************************************************
# Actual:	 them
# Guess:	 Sea
# Conf:	  0.1446727216243744
# 	 False
# ***************************************************************************************************************
# Actual:	 this
# Guess:	 this
# Conf:	  0.8794010877609253
# 	 True
# ***************************************************************************************************************
# Actual:	 this
# Guess:	 thes
# Conf:	  0.3740309178829193
# 	 False
# ***************************************************************************************************************
# Actual:	 time.
# Guess:	 kwen
# Conf:	  0.11273759603500366
# 	 False
# ***************************************************************************************************************
# Actual:	 tips
# Guess:	 ties
# Conf:	  0.3153669536113739
# 	 False
# ***************************************************************************************************************
# Actual:	 to
# Guess:	 to
# Conf:	  0.4444141089916229
# 	 True
# ***************************************************************************************************************
# Actual:	 to
# Guess:	 he
# Conf:	  0.2209147959947586
# 	 False
# ***************************************************************************************************************
# Actual:	 to
# Guess:	 to
# Conf:	  0.4833844006061554
# 	 True
# ***************************************************************************************************************
# Actual:	 to
# Guess:	 to
# Conf:	  0.9433696269989014
# 	 True
# ***************************************************************************************************************
# Actual:	 today
# Guess:	 tedax
# Conf:	  0.4399358928203583
# 	 False
# ***************************************************************************************************************
# Actual:	 will
# Guess:	 will
# Conf:	  0.8371655941009521
# 	 True
# ***************************************************************************************************************
# Actual:	 will
# Guess:	 mrl
# Conf:	  0.09476662427186966
# 	 False
# ***************************************************************************************************************
# Actual:	 will
# Guess:	 will
# Conf:	  0.9580297470092773
# 	 True
# ***************************************************************************************************************
# Actual:	 world'.
# Guess:	 ward'
# Conf:	  0.09024856239557266
# 	 False
# ***************************************************************************************************************
# Actual:	 year
# Guess:	 year
# Conf:	  0.5035416483879089
# 	 True
# ***************************************************************************************************************
# Actual:	 Yes
# Guess:	 Ye
# Conf:	  0.3737577199935913
# 	 False
# ***************************************************************************************************************
